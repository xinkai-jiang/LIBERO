# %% [markdown]
# # Overview
# This jupyter notebook covers the following contents:
# 1. Default configuration in LIBERO
# 2. Basic information about available LIBERO benchmarks
#    - Get a dictionary of mapping from benchmark name to benchmark class
#    - Check the integrity of benchmarks
#    - Check the integrity of init files
#    - Visualize all the init states of a task
#    - Download datasets
#    - Get information about a demonstration file and replay a trajectory

# %%
from libero.libero import benchmark
benchmark.get_benchmark_dict(True)
from libero.libero import benchmark, get_libero_path, set_libero_default_path
import os
from termcolor import colored
# Out:
# Registering benchmark LIBERO_SPATIAL
# Registering benchmark LIBERO_OBJECT
# Registering benchmark LIBERO_GOAL
# Registering benchmark LIBERO_90
# Registering benchmark T2
# Registering benchmark T3
# Registering benchmark T4
# Registering benchmark LIBERO_10
# Registering benchmark LIBERO_100
# Available benchmarks:
# 	libero_spatial
# 	libero_object
# 	libero_goal
# 	libero_90
# 	t2
# 	t3
# 	t4
# 	libero_10
# 	libero_100

# %% [markdown]
# ## 1. Default file paths

# %% [markdown]
# All the paths are retrieved from a yaml config file located at `~/.libero/config.yaml`. And the default paths are set to relative to the libero codebase.

# %%
benchmark_root_path = get_libero_path("benchmark_root")
init_states_default_path = get_libero_path("init_states")
datasets_default_path = get_libero_path("datasets")
bddl_files_default_path = get_libero_path("bddl_files")
print("Default benchmark root path: ", benchmark_root_path)
print("Default dataset root path: ", datasets_default_path)
print("Default bddl files root path: ", bddl_files_default_path)
# Out:
# Default benchmark root path:  /home/xinkai/repository/LIBERO/libero/libero
# Default dataset root path:  /home/xinkai/repository/LIBERO/libero/libero/../datasets
# Default bddl files root path:  /home/xinkai/repository/LIBERO/libero/libero/./bddl_files

# %% [markdown]
# Now if you want to point your codebase to custom path, you can use `set_libero_path` function to do that. Notice that all the paths change according to `benchmark_root` value.

# %%
set_libero_default_path(os.path.join(os.path.expanduser("~"), "custom_project"))
benchmark_root_path = get_libero_path("benchmark_root")
init_states_default_path = get_libero_path("init_states")
datasets_default_path = get_libero_path("datasets")
bddl_files_default_path = get_libero_path("bddl_files")
print("Default benchmark root path: ", benchmark_root_path)
print("Default dataset root path: ", datasets_default_path)
print("Default bddl files root path: ", bddl_files_default_path)

# If nothing is specified in the `set_libero_default_path` function, the path will be changed back to the default path
# We will set back the path to the default path for the subsequent examples
set_libero_default_path()
benchmark_root_path = get_libero_path("benchmark_root")
init_states_default_path = get_libero_path("init_states")
datasets_default_path = get_libero_path("datasets")
bddl_files_default_path = get_libero_path("bddl_files")
print("Default benchmark root path: ", benchmark_root_path)
print("Default dataset root path: ", datasets_default_path)
print("Default bddl files root path: ", bddl_files_default_path)
# Out:
# [Warning] You are changing the default path for Libero config. This will affect all the paths in the config file.
# [Warning]: assets path /home/xinkai/custom_project/./assets does not exist!
# [Warning]: bddl_files path /home/xinkai/custom_project/./bddl_files does not exist!
# [Warning]: benchmark_root path /home/xinkai/custom_project does not exist!
# [Warning]: datasets path /home/xinkai/custom_project/../datasets does not exist!
# [Warning]: init_states path /home/xinkai/custom_project/./init_files does not exist!
# [Warning]: assets path /home/xinkai/custom_project/./assets does not exist!
# [Warning]: bddl_files path /home/xinkai/custom_project/./bddl_files does not exist!
# [Warning]: benchmark_root path /home/xinkai/custom_project does not exist!
# [Warning]: datasets path /home/xinkai/custom_project/../datasets does not exist!
# [Warning]: init_states path /home/xinkai/custom_project/./init_files does not exist!
# [Warning]: assets path /home/xinkai/custom_project/./assets does not exist!
# [Warning]: bddl_files path /home/xinkai/custom_project/./bddl_files does not exist!
# [Warning]: benchmark_root path /home/xinkai/custom_project does not exist!
# [Warning]: datasets path /home/xinkai/custom_project/../datasets does not exist!
# [Warning]: init_states path /home/xinkai/custom_project/./init_files does not exist!
# [Warning]: assets path /home/xinkai/custom_project/./assets does not exist!
# [Warning]: bddl_files path /home/xinkai/custom_project/./bddl_files does not exist!
# [Warning]: benchmark_root path /home/xinkai/custom_project does not exist!
# [Warning]: datasets path /home/xinkai/custom_project/../datasets does not exist!
# [Warning]: init_states path /home/xinkai/custom_project/./init_files does not exist!
# Default benchmark root path:  /home/xinkai/custom_project
# Default dataset root path:  /home/xinkai/custom_project/../datasets
# Default bddl files root path:  /home/xinkai/custom_project/./bddl_files
# [Warning] You are changing the default path for Libero config. This will affect all the paths in the config file.
# Default benchmark root path:  /home/xinkai/repository/LIBERO/libero/libero
# Default dataset root path:  /home/xinkai/repository/LIBERO/libero/libero/../datasets
# Default bddl files root path:  /home/xinkai/repository/LIBERO/libero/libero/./bddl_files

# %% [markdown]
# # 2. See available benchmarks

# %% [markdown]
# ### 2.1 Get a dictionary of mapping from benchmark name to benchmark class

# %%
benchmark_dict = benchmark.get_benchmark_dict(True)
print(benchmark_dict)
# Out:
# Available benchmarks:
# 	libero_spatial
# 	libero_object
# 	libero_goal
# 	libero_90
# 	t2
# 	t3
# 	t4
# 	libero_10
# 	libero_100
# {'libero_spatial': <class 'libero.libero.benchmark.LIBERO_SPATIAL'>, 'libero_object': <class 'libero.libero.benchmark.LIBERO_OBJECT'>, 'libero_goal': <class 'libero.libero.benchmark.LIBERO_GOAL'>, 'libero_90': <class 'libero.libero.benchmark.LIBERO_90'>, 't2': <class 'libero.libero.benchmark.T2'>, 't3': <class 'libero.libero.benchmark.T3'>, 't4': <class 'libero.libero.benchmark.T4'>, 'libero_10': <class 'libero.libero.benchmark.LIBERO_10'>, 'libero_100': <class 'libero.libero.benchmark.LIBERO_100'>}

# %% [markdown]
# ### 2.2 Check the integrity of benchmarks

# %%
# initialize a benchmark
# benchmark_instance = benchmark_dict["libero_10"]()
print("Available benchmarks: ", list(benchmark_dict.keys()))
benchmark_instance = benchmark_dict["t3"]()
num_tasks = benchmark_instance.get_num_tasks()
# see how many tasks involved in the benchmark
print(f"{num_tasks} tasks in the benchmark {benchmark_instance.name}: ")

# Check if all the task names and their bddl file names
task_names = benchmark_instance.get_task_names()
print("The benchmark contains the following tasks:")
for i in range(num_tasks):
    task_name = task_names[i]
    task = benchmark_instance.get_task(i)
    bddl_file = os.path.join(bddl_files_default_path, task.problem_folder, task.bddl_file)
    print(f"\t {task_name}, detail definition stored in {bddl_file}")
    if not os.path.exists(bddl_file):
        print(colored(f"[error] bddl file {bddl_file} cannot be found. Check your paths", "red"))
# Out:
# Available benchmarks:  ['libero_spatial', 'libero_object', 'libero_goal', 'libero_90', 't2', 't3', 't4', 'libero_10', 'libero_100']
# 1 tasks in the benchmark t3:
# The benchmark contains the following tasks:
# 	 STUDY_SCENE4_pick_up_the_book_in_the_middle_and_place_it_on_the_cabinet_shelf, detail definition stored in /home/xinkai/repository/LIBERO/libero/libero/./bddl_files/t3/STUDY_SCENE4_pick_up_the_book_in_the_middle_and_place_it_on_the_cabinet_shelf.bddl

# %% [markdown]
# ### 2.3 Check the integrity of init files

# %%
# Check if all the init states files exist for tasks
task_names = benchmark_instance.get_task_names()
print("The benchmark contains the following tasks:")
for i in range(num_tasks):
    task_name = task_names[i]
    task = benchmark_instance.get_task(i)
    init_states_path = os.path.join(init_states_default_path, task.problem_folder, task.init_states_file)
    if not os.path.exists(init_states_path):
        print(colored(f"[error] the init states {init_states_path} cannot be found. Check your paths", "red"))
print(f"An example of init file is named like this: {task.init_states_file}")

# Load torch init files
init_states = benchmark_instance.get_task_init_states(0)
# Init states in the same (num_init_rollouts, num_simulation_states)
print(init_states.shape)
# Out:
# The benchmark contains the following tasks:
# An example of init file is named like this: STUDY_SCENE4_pick_up_the_book_in_the_middle_and_place_it_on_the_cabinet_shelf.pruned_init
# (50, 58)

# %% [markdown]
# ### 2.4 Visualize all the init states of a task

# %%
from libero.libero.envs import OffScreenRenderEnv
from IPython.display import display
from PIL import Image

import torch
import torchvision

# task_id is the (task_id + 1)th task in the benchmark
task_id = 0
task = benchmark_instance.get_task(task_id)

env_args = {
    "bddl_file_name": os.path.join(bddl_files_default_path, task.problem_folder, task.bddl_file),
    "camera_heights": 128,
    "camera_widths": 128
}

env = OffScreenRenderEnv(**env_args)


init_states = benchmark_instance.get_task_init_states(task_id)

# Fix random seeds for reproducibility
env.seed(0)

def make_grid(images, nrow=8, padding=2, normalize=False, pad_value=0):
    """Make a grid of images. Make sure images is a 4D tensor in the shape of (B x C x H x W)) or a list of torch tensors."""
    grid_image = torchvision.utils.make_grid(images, nrow=nrow, padding=padding, normalize=normalize, pad_value=pad_value).permute(1, 2, 0)
    return grid_image

images = []
env.reset()
for eval_index in range(len(init_states)):
    env.set_init_state(init_states[eval_index])

    for _ in range(5):
        obs, _, _, _ = env.step([0.] * 7)
    images.append(torch.from_numpy(obs["agentview_image"]).permute(2, 0, 1))

# # images = torch.stack(images, dim=0).permute(0, 3, 1, 2)
# print(images.shape)
grid_image = make_grid(images, nrow=10, padding=2, pad_value=0)
display(Image.fromarray(grid_image.numpy()[::-1]))
env.close()
# Out:
# [robosuite WARNING] No private macro file found! (macros.py:53)
# [robosuite WARNING] It is recommended to use a private macro file (macros.py:54)
# [robosuite WARNING] To setup, run: python /home/xinkai/miniconda3/envs/libero/lib/python3.8/site-packages/robosuite/scripts/setup_macros.py (macros.py:55)
# <PIL.Image.Image image mode=RGB size=1302x652>

# %% [markdown]
# ### 2.5 Download datasets

# %%
import libero.libero.utils.download_utils as download_utils

download_dir = get_libero_path("datasets")
datasets = "libero_90" # Can specify "all", "libero_goal", "libero_spatial", "libero_object", "libero_100"

libero_datasets_exist = download_utils.check_libero_dataset(download_dir=download_dir)

if not libero_datasets_exist:
    download_utils.libero_dataset_download(download_dir=download_dir, datasets=datasets)

# Check if the demo files exist
demo_files = [os.path.join(datasets_default_path, benchmark_instance.get_task_demonstration(i)) for i in range(num_tasks)]
for demo_file in demo_files:
    if not os.path.exists(demo_file):
        print(colored(f"[error] demo file {demo_file} cannot be found. Check your paths", "red"))
# Out:
# [X] Dataset libero_object is complete
# [X] Dataset libero_goal is complete
# [X] Dataset libero_spatial is complete
# [X] Dataset libero_10 is complete
# [X] Dataset libero_90 is complete

# %% [markdown]
# ### 2.6 Get information about a demonstration file and replay a trajectory

# %%
import h5py
from libero.libero.utils.dataset_utils import get_dataset_info
from IPython.display import HTML
import imageio

# example_demo_file = demo_files[0]
# example_demo_file = os.path.join(datasets_default_path, "t4/KITCHEN_SCENE8_turn_off_the_stove_demo.hdf5")
example_demo_file = os.path.join(datasets_default_path, "t4/KITCHEN_SCENE9_turn_on_the_stove_and_put_the_frying_pan_on_it_demo.hdf5")
print("Example demo file: ", example_demo_file)
# Print the dataset info. We have a standalone script for doing the same thing available at `scripts/get_dataset_info.py`
get_dataset_info(example_demo_file)

with h5py.File(example_demo_file, "r") as f:
    images = f["data/demo_1/obs/agentview_rgb"][()]

video_writer = imageio.get_writer("output.mp4", fps=60)
for image in images:
    video_writer.append_data(image[::-1])
video_writer.close()

HTML("""
    <video width="640" height="480" controls>
        <source src="output.mp4" type="video/mp4">
    </video>
    <script>
        var video = document.getElementsByTagName('video')[0];
        video.playbackRate = 2.0; // Increase the playback speed to 2x
        </script>    
""")
# Out:
# Example demo file:  /home/xinkai/repository/LIBERO/libero/libero/../datasets/t4/KITCHEN_SCENE9_turn_on_the_stove_and_put_the_frying_pan_on_it_demo.hdf5
#
# total transitions: 28425
# total trajectories: 50
# traj length mean: 568.5
# traj length std: 44.93339515327102
# traj length min: 455
# traj length max: 685
# action min: -10.0
# action max: 10.0
# language instruction: turn on the stove and put the frying pan on it
#
# ==== Filter Keys ====
# no filter keys
#
#
# ==== Env Meta ====
# {
#     "type": 1,
#     "env_name": "Libero_Kitchen_Tabletop_Manipulation",
#     "problem_name": "libero_kitchen_tabletop_manipulation",
#     "bddl_file": "/home/xinkai/repository/LIBERO/libero/libero/bddl_files/libero_90/KITCHEN_SCENE9_turn_on_the_stove_and_put_the_frying_pan_on_it.bddl",
#     "env_kwargs": {
#         "robots": [
#             "Panda"
#         ],
#         "controller_configs": {
#             "type": "OSC_POSE",
#             "input_max": 1,
#             "input_min": -1,
#             "output_max": [
#                 0.05,
#                 0.05,
#                 0.05,
#                 0.5,
#                 0.5,
#                 0.5
#             ],
#             "output_min": [
#                 -0.05,
#                 -0.05,
#                 -0.05,
#                 -0.5,
#                 -0.5,
#                 -0.5
#             ],
#             "kp": 150,
#             "damping_ratio": 1,
#             "impedance_mode": "fixed",
#             "kp_limits": [
#                 0,
#                 300
#             ],
#             "damping_ratio_limits": [
#                 0,
#                 10
#             ],
#             "position_limits": null,
#             "orientation_limits": null,
#             "uncouple_pos_ori": true,
#             "control_delta": true,
#             "interpolation": null,
#             "ramp_ratio": 0.2
#         },
#         "bddl_file_name": "/home/xinkai/repository/LIBERO/libero/libero/bddl_files/libero_90/KITCHEN_SCENE9_turn_on_the_stove_and_put_the_frying_pan_on_it.bddl",
#         "has_renderer": false,
#         "has_offscreen_renderer": true,
#         "ignore_done": true,
#         "use_camera_obs": true,
#         "camera_depths": false,
#         "camera_names": [
#             "robot0_eye_in_hand",
#             "agentview"
#         ],
#         "reward_shaping": true,
#         "control_freq": 20,
#         "camera_heights": 128,
#         "camera_widths": 128,
#         "camera_segmentations": null
#     }
# }
#
# ==== Dataset Structure ====
# episode demo_0 with 579 transitions
#     key: actions with shape (579, 7)
#     key: dones with shape (579,)
#     key: obs
#         observation key agentview_rgb with shape (579, 128, 128, 3)
#         observation key ee_ori with shape (579, 3)
#         observation key ee_pos with shape (579, 3)
#         observation key ee_states with shape (579, 6)
#         observation key eye_in_hand_rgb with shape (579, 128, 128, 3)
#         observation key gripper_states with shape (579, 2)
#         observation key joint_states with shape (579, 7)
#     key: rewards with shape (579,)
#     key: robot_states with shape (579, 9)
#     key: states with shape (579, 47)
# episode demo_1 with 587 transitions
#     key: actions with shape (587, 7)
#     key: dones with shape (587,)
#     key: obs
#         observation key agentview_rgb with shape (587, 128, 128, 3)
#         observation key ee_ori with shape (587, 3)
#         observation key ee_pos with shape (587, 3)
#         observation key ee_states with shape (587, 6)
#         observation key eye_in_hand_rgb with shape (587, 128, 128, 3)
#         observation key gripper_states with shape (587, 2)
#         observation key joint_states with shape (587, 7)
#     key: rewards with shape (587,)
#     key: robot_states with shape (587, 9)
#     key: states with shape (587, 47)
# episode demo_2 with 613 transitions
#     key: actions with shape (613, 7)
#     key: dones with shape (613,)
#     key: obs
#         observation key agentview_rgb with shape (613, 128, 128, 3)
#         observation key ee_ori with shape (613, 3)
#         observation key ee_pos with shape (613, 3)
#         observation key ee_states with shape (613, 6)
#         observation key eye_in_hand_rgb with shape (613, 128, 128, 3)
#         observation key gripper_states with shape (613, 2)
#         observation key joint_states with shape (613, 7)
#     key: rewards with shape (613,)
#     key: robot_states with shape (613, 9)
#     key: states with shape (613, 47)
# episode demo_3 with 559 transitions
#     key: actions with shape (559, 7)
#     key: dones with shape (559,)
#     key: obs
#         observation key agentview_rgb with shape (559, 128, 128, 3)
#         observation key ee_ori with shape (559, 3)
#         observation key ee_pos with shape (559, 3)
#         observation key ee_states with shape (559, 6)
#         observation key eye_in_hand_rgb with shape (559, 128, 128, 3)
#         observation key gripper_states with shape (559, 2)
#         observation key joint_states with shape (559, 7)
#     key: rewards with shape (559,)
#     key: robot_states with shape (559, 9)
#     key: states with shape (559, 47)
# episode demo_4 with 455 transitions
#     key: actions with shape (455, 7)
#     key: dones with shape (455,)
#     key: obs
#         observation key agentview_rgb with shape (455, 128, 128, 3)
#         observation key ee_ori with shape (455, 3)
#         observation key ee_pos with shape (455, 3)
#         observation key ee_states with shape (455, 6)
#         observation key eye_in_hand_rgb with shape (455, 128, 128, 3)
#         observation key gripper_states with shape (455, 2)
#         observation key joint_states with shape (455, 7)
#     key: rewards with shape (455,)
#     key: robot_states with shape (455, 9)
#     key: states with shape (455, 47)
# episode demo_5 with 575 transitions
#     key: actions with shape (575, 7)
#     key: dones with shape (575,)
#     key: obs
#         observation key agentview_rgb with shape (575, 128, 128, 3)
#         observation key ee_ori with shape (575, 3)
#         observation key ee_pos with shape (575, 3)
#         observation key ee_states with shape (575, 6)
#         observation key eye_in_hand_rgb with shape (575, 128, 128, 3)
#         observation key gripper_states with shape (575, 2)
#         observation key joint_states with shape (575, 7)
#     key: rewards with shape (575,)
#     key: robot_states with shape (575, 9)
#     key: states with shape (575, 47)
# episode demo_6 with 559 transitions
#     key: actions with shape (559, 7)
#     key: dones with shape (559,)
#     key: obs
#         observation key agentview_rgb with shape (559, 128, 128, 3)
#         observation key ee_ori with shape (559, 3)
#         observation key ee_pos with shape (559, 3)
#         observation key ee_states with shape (559, 6)
#         observation key eye_in_hand_rgb with shape (559, 128, 128, 3)
#         observation key gripper_states with shape (559, 2)
#         observation key joint_states with shape (559, 7)
#     key: rewards with shape (559,)
#     key: robot_states with shape (559, 9)
#     key: states with shape (559, 47)
# episode demo_7 with 523 transitions
#     key: actions with shape (523, 7)
#     key: dones with shape (523,)
#     key: obs
#         observation key agentview_rgb with shape (523, 128, 128, 3)
#         observation key ee_ori with shape (523, 3)
#         observation key ee_pos with shape (523, 3)
#         observation key ee_states with shape (523, 6)
#         observation key eye_in_hand_rgb with shape (523, 128, 128, 3)
#         observation key gripper_states with shape (523, 2)
#         observation key joint_states with shape (523, 7)
#     key: rewards with shape (523,)
#     key: robot_states with shape (523, 9)
#     key: states with shape (523, 47)
# episode demo_8 with 604 transitions
#     key: actions with shape (604, 7)
#     key: dones with shape (604,)
#     key: obs
#         observation key agentview_rgb with shape (604, 128, 128, 3)
#         observation key ee_ori with shape (604, 3)
#         observation key ee_pos with shape (604, 3)
#         observation key ee_states with shape (604, 6)
#         observation key eye_in_hand_rgb with shape (604, 128, 128, 3)
#         observation key gripper_states with shape (604, 2)
#         observation key joint_states with shape (604, 7)
#     key: rewards with shape (604,)
#     key: robot_states with shape (604, 9)
#     key: states with shape (604, 47)
# episode demo_9 with 565 transitions
#     key: actions with shape (565, 7)
#     key: dones with shape (565,)
#     key: obs
#         observation key agentview_rgb with shape (565, 128, 128, 3)
#         observation key ee_ori with shape (565, 3)
#         observation key ee_pos with shape (565, 3)
#         observation key ee_states with shape (565, 6)
#         observation key eye_in_hand_rgb with shape (565, 128, 128, 3)
#         observation key gripper_states with shape (565, 2)
#         observation key joint_states with shape (565, 7)
#     key: rewards with shape (565,)
#     key: robot_states with shape (565, 9)
#     key: states with shape (565, 47)
# episode demo_10 with 532 transitions
#     key: actions with shape (532, 7)
#     key: dones with shape (532,)
#     key: obs
#         observation key agentview_rgb with shape (532, 128, 128, 3)
#         observation key ee_ori with shape (532, 3)
#         observation key ee_pos with shape (532, 3)
#         observation key ee_states with shape (532, 6)
#         observation key eye_in_hand_rgb with shape (532, 128, 128, 3)
#         observation key gripper_states with shape (532, 2)
#         observation key joint_states with shape (532, 7)
#     key: rewards with shape (532,)
#     key: robot_states with shape (532, 9)
#     key: states with shape (532, 47)
# episode demo_11 with 558 transitions
#     key: actions with shape (558, 7)
#     key: dones with shape (558,)
#     key: obs
#         observation key agentview_rgb with shape (558, 128, 128, 3)
#         observation key ee_ori with shape (558, 3)
#         observation key ee_pos with shape (558, 3)
#         observation key ee_states with shape (558, 6)
#         observation key eye_in_hand_rgb with shape (558, 128, 128, 3)
#         observation key gripper_states with shape (558, 2)
#         observation key joint_states with shape (558, 7)
#     key: rewards with shape (558,)
#     key: robot_states with shape (558, 9)
#     key: states with shape (558, 47)
# episode demo_12 with 685 transitions
#     key: actions with shape (685, 7)
#     key: dones with shape (685,)
#     key: obs
#         observation key agentview_rgb with shape (685, 128, 128, 3)
#         observation key ee_ori with shape (685, 3)
#         observation key ee_pos with shape (685, 3)
#         observation key ee_states with shape (685, 6)
#         observation key eye_in_hand_rgb with shape (685, 128, 128, 3)
#         observation key gripper_states with shape (685, 2)
#         observation key joint_states with shape (685, 7)
#     key: rewards with shape (685,)
#     key: robot_states with shape (685, 9)
#     key: states with shape (685, 47)
# episode demo_13 with 561 transitions
#     key: actions with shape (561, 7)
#     key: dones with shape (561,)
#     key: obs
#         observation key agentview_rgb with shape (561, 128, 128, 3)
#         observation key ee_ori with shape (561, 3)
#         observation key ee_pos with shape (561, 3)
#         observation key ee_states with shape (561, 6)
#         observation key eye_in_hand_rgb with shape (561, 128, 128, 3)
#         observation key gripper_states with shape (561, 2)
#         observation key joint_states with shape (561, 7)
#     key: rewards with shape (561,)
#     key: robot_states with shape (561, 9)
#     key: states with shape (561, 47)
# episode demo_14 with 595 transitions
#     key: actions with shape (595, 7)
#     key: dones with shape (595,)
#     key: obs
#         observation key agentview_rgb with shape (595, 128, 128, 3)
#         observation key ee_ori with shape (595, 3)
#         observation key ee_pos with shape (595, 3)
#         observation key ee_states with shape (595, 6)
#         observation key eye_in_hand_rgb with shape (595, 128, 128, 3)
#         observation key gripper_states with shape (595, 2)
#         observation key joint_states with shape (595, 7)
#     key: rewards with shape (595,)
#     key: robot_states with shape (595, 9)
#     key: states with shape (595, 47)
# episode demo_15 with 598 transitions
#     key: actions with shape (598, 7)
#     key: dones with shape (598,)
#     key: obs
#         observation key agentview_rgb with shape (598, 128, 128, 3)
#         observation key ee_ori with shape (598, 3)
#         observation key ee_pos with shape (598, 3)
#         observation key ee_states with shape (598, 6)
#         observation key eye_in_hand_rgb with shape (598, 128, 128, 3)
#         observation key gripper_states with shape (598, 2)
#         observation key joint_states with shape (598, 7)
#     key: rewards with shape (598,)
#     key: robot_states with shape (598, 9)
#     key: states with shape (598, 47)
# episode demo_16 with 513 transitions
#     key: actions with shape (513, 7)
#     key: dones with shape (513,)
#     key: obs
#         observation key agentview_rgb with shape (513, 128, 128, 3)
#         observation key ee_ori with shape (513, 3)
#         observation key ee_pos with shape (513, 3)
#         observation key ee_states with shape (513, 6)
#         observation key eye_in_hand_rgb with shape (513, 128, 128, 3)
#         observation key gripper_states with shape (513, 2)
#         observation key joint_states with shape (513, 7)
#     key: rewards with shape (513,)
#     key: robot_states with shape (513, 9)
#     key: states with shape (513, 47)
# episode demo_17 with 498 transitions
#     key: actions with shape (498, 7)
#     key: dones with shape (498,)
#     key: obs
#         observation key agentview_rgb with shape (498, 128, 128, 3)
#         observation key ee_ori with shape (498, 3)
#         observation key ee_pos with shape (498, 3)
#         observation key ee_states with shape (498, 6)
#         observation key eye_in_hand_rgb with shape (498, 128, 128, 3)
#         observation key gripper_states with shape (498, 2)
#         observation key joint_states with shape (498, 7)
#     key: rewards with shape (498,)
#     key: robot_states with shape (498, 9)
#     key: states with shape (498, 47)
# episode demo_18 with 607 transitions
#     key: actions with shape (607, 7)
#     key: dones with shape (607,)
#     key: obs
#         observation key agentview_rgb with shape (607, 128, 128, 3)
#         observation key ee_ori with shape (607, 3)
#         observation key ee_pos with shape (607, 3)
#         observation key ee_states with shape (607, 6)
#         observation key eye_in_hand_rgb with shape (607, 128, 128, 3)
#         observation key gripper_states with shape (607, 2)
#         observation key joint_states with shape (607, 7)
#     key: rewards with shape (607,)
#     key: robot_states with shape (607, 9)
#     key: states with shape (607, 47)
# episode demo_19 with 529 transitions
#     key: actions with shape (529, 7)
#     key: dones with shape (529,)
#     key: obs
#         observation key agentview_rgb with shape (529, 128, 128, 3)
#         observation key ee_ori with shape (529, 3)
#         observation key ee_pos with shape (529, 3)
#         observation key ee_states with shape (529, 6)
#         observation key eye_in_hand_rgb with shape (529, 128, 128, 3)
#         observation key gripper_states with shape (529, 2)
#         observation key joint_states with shape (529, 7)
#     key: rewards with shape (529,)
#     key: robot_states with shape (529, 9)
#     key: states with shape (529, 47)
# episode demo_20 with 523 transitions
#     key: actions with shape (523, 7)
#     key: dones with shape (523,)
#     key: obs
#         observation key agentview_rgb with shape (523, 128, 128, 3)
#         observation key ee_ori with shape (523, 3)
#         observation key ee_pos with shape (523, 3)
#         observation key ee_states with shape (523, 6)
#         observation key eye_in_hand_rgb with shape (523, 128, 128, 3)
#         observation key gripper_states with shape (523, 2)
#         observation key joint_states with shape (523, 7)
#     key: rewards with shape (523,)
#     key: robot_states with shape (523, 9)
#     key: states with shape (523, 47)
# episode demo_21 with 614 transitions
#     key: actions with shape (614, 7)
#     key: dones with shape (614,)
#     key: obs
#         observation key agentview_rgb with shape (614, 128, 128, 3)
#         observation key ee_ori with shape (614, 3)
#         observation key ee_pos with shape (614, 3)
#         observation key ee_states with shape (614, 6)
#         observation key eye_in_hand_rgb with shape (614, 128, 128, 3)
#         observation key gripper_states with shape (614, 2)
#         observation key joint_states with shape (614, 7)
#     key: rewards with shape (614,)
#     key: robot_states with shape (614, 9)
#     key: states with shape (614, 47)
# episode demo_22 with 547 transitions
#     key: actions with shape (547, 7)
#     key: dones with shape (547,)
#     key: obs
#         observation key agentview_rgb with shape (547, 128, 128, 3)
#         observation key ee_ori with shape (547, 3)
#         observation key ee_pos with shape (547, 3)
#         observation key ee_states with shape (547, 6)
#         observation key eye_in_hand_rgb with shape (547, 128, 128, 3)
#         observation key gripper_states with shape (547, 2)
#         observation key joint_states with shape (547, 7)
#     key: rewards with shape (547,)
#     key: robot_states with shape (547, 9)
#     key: states with shape (547, 47)
# episode demo_23 with 516 transitions
#     key: actions with shape (516, 7)
#     key: dones with shape (516,)
#     key: obs
#         observation key agentview_rgb with shape (516, 128, 128, 3)
#         observation key ee_ori with shape (516, 3)
#         observation key ee_pos with shape (516, 3)
#         observation key ee_states with shape (516, 6)
#         observation key eye_in_hand_rgb with shape (516, 128, 128, 3)
#         observation key gripper_states with shape (516, 2)
#         observation key joint_states with shape (516, 7)
#     key: rewards with shape (516,)
#     key: robot_states with shape (516, 9)
#     key: states with shape (516, 47)
# episode demo_24 with 623 transitions
#     key: actions with shape (623, 7)
#     key: dones with shape (623,)
#     key: obs
#         observation key agentview_rgb with shape (623, 128, 128, 3)
#         observation key ee_ori with shape (623, 3)
#         observation key ee_pos with shape (623, 3)
#         observation key ee_states with shape (623, 6)
#         observation key eye_in_hand_rgb with shape (623, 128, 128, 3)
#         observation key gripper_states with shape (623, 2)
#         observation key joint_states with shape (623, 7)
#     key: rewards with shape (623,)
#     key: robot_states with shape (623, 9)
#     key: states with shape (623, 47)
# episode demo_25 with 569 transitions
#     key: actions with shape (569, 7)
#     key: dones with shape (569,)
#     key: obs
#         observation key agentview_rgb with shape (569, 128, 128, 3)
#         observation key ee_ori with shape (569, 3)
#         observation key ee_pos with shape (569, 3)
#         observation key ee_states with shape (569, 6)
#         observation key eye_in_hand_rgb with shape (569, 128, 128, 3)
#         observation key gripper_states with shape (569, 2)
#         observation key joint_states with shape (569, 7)
#     key: rewards with shape (569,)
#     key: robot_states with shape (569, 9)
#     key: states with shape (569, 47)
# episode demo_26 with 590 transitions
#     key: actions with shape (590, 7)
#     key: dones with shape (590,)
#     key: obs
#         observation key agentview_rgb with shape (590, 128, 128, 3)
#         observation key ee_ori with shape (590, 3)
#         observation key ee_pos with shape (590, 3)
#         observation key ee_states with shape (590, 6)
#         observation key eye_in_hand_rgb with shape (590, 128, 128, 3)
#         observation key gripper_states with shape (590, 2)
#         observation key joint_states with shape (590, 7)
#     key: rewards with shape (590,)
#     key: robot_states with shape (590, 9)
#     key: states with shape (590, 47)
# episode demo_27 with 572 transitions
#     key: actions with shape (572, 7)
#     key: dones with shape (572,)
#     key: obs
#         observation key agentview_rgb with shape (572, 128, 128, 3)
#         observation key ee_ori with shape (572, 3)
#         observation key ee_pos with shape (572, 3)
#         observation key ee_states with shape (572, 6)
#         observation key eye_in_hand_rgb with shape (572, 128, 128, 3)
#         observation key gripper_states with shape (572, 2)
#         observation key joint_states with shape (572, 7)
#     key: rewards with shape (572,)
#     key: robot_states with shape (572, 9)
#     key: states with shape (572, 47)
# episode demo_28 with 546 transitions
#     key: actions with shape (546, 7)
#     key: dones with shape (546,)
#     key: obs
#         observation key agentview_rgb with shape (546, 128, 128, 3)
#         observation key ee_ori with shape (546, 3)
#         observation key ee_pos with shape (546, 3)
#         observation key ee_states with shape (546, 6)
#         observation key eye_in_hand_rgb with shape (546, 128, 128, 3)
#         observation key gripper_states with shape (546, 2)
#         observation key joint_states with shape (546, 7)
#     key: rewards with shape (546,)
#     key: robot_states with shape (546, 9)
#     key: states with shape (546, 47)
# episode demo_29 with 636 transitions
#     key: actions with shape (636, 7)
#     key: dones with shape (636,)
#     key: obs
#         observation key agentview_rgb with shape (636, 128, 128, 3)
#         observation key ee_ori with shape (636, 3)
#         observation key ee_pos with shape (636, 3)
#         observation key ee_states with shape (636, 6)
#         observation key eye_in_hand_rgb with shape (636, 128, 128, 3)
#         observation key gripper_states with shape (636, 2)
#         observation key joint_states with shape (636, 7)
#     key: rewards with shape (636,)
#     key: robot_states with shape (636, 9)
#     key: states with shape (636, 47)
# episode demo_30 with 585 transitions
#     key: actions with shape (585, 7)
#     key: dones with shape (585,)
#     key: obs
#         observation key agentview_rgb with shape (585, 128, 128, 3)
#         observation key ee_ori with shape (585, 3)
#         observation key ee_pos with shape (585, 3)
#         observation key ee_states with shape (585, 6)
#         observation key eye_in_hand_rgb with shape (585, 128, 128, 3)
#         observation key gripper_states with shape (585, 2)
#         observation key joint_states with shape (585, 7)
#     key: rewards with shape (585,)
#     key: robot_states with shape (585, 9)
#     key: states with shape (585, 47)
# episode demo_31 with 584 transitions
#     key: actions with shape (584, 7)
#     key: dones with shape (584,)
#     key: obs
#         observation key agentview_rgb with shape (584, 128, 128, 3)
#         observation key ee_ori with shape (584, 3)
#         observation key ee_pos with shape (584, 3)
#         observation key ee_states with shape (584, 6)
#         observation key eye_in_hand_rgb with shape (584, 128, 128, 3)
#         observation key gripper_states with shape (584, 2)
#         observation key joint_states with shape (584, 7)
#     key: rewards with shape (584,)
#     key: robot_states with shape (584, 9)
#     key: states with shape (584, 47)
# episode demo_32 with 517 transitions
#     key: actions with shape (517, 7)
#     key: dones with shape (517,)
#     key: obs
#         observation key agentview_rgb with shape (517, 128, 128, 3)
#         observation key ee_ori with shape (517, 3)
#         observation key ee_pos with shape (517, 3)
#         observation key ee_states with shape (517, 6)
#         observation key eye_in_hand_rgb with shape (517, 128, 128, 3)
#         observation key gripper_states with shape (517, 2)
#         observation key joint_states with shape (517, 7)
#     key: rewards with shape (517,)
#     key: robot_states with shape (517, 9)
#     key: states with shape (517, 47)
# episode demo_33 with 628 transitions
#     key: actions with shape (628, 7)
#     key: dones with shape (628,)
#     key: obs
#         observation key agentview_rgb with shape (628, 128, 128, 3)
#         observation key ee_ori with shape (628, 3)
#         observation key ee_pos with shape (628, 3)
#         observation key ee_states with shape (628, 6)
#         observation key eye_in_hand_rgb with shape (628, 128, 128, 3)
#         observation key gripper_states with shape (628, 2)
#         observation key joint_states with shape (628, 7)
#     key: rewards with shape (628,)
#     key: robot_states with shape (628, 9)
#     key: states with shape (628, 47)
# episode demo_34 with 516 transitions
#     key: actions with shape (516, 7)
#     key: dones with shape (516,)
#     key: obs
#         observation key agentview_rgb with shape (516, 128, 128, 3)
#         observation key ee_ori with shape (516, 3)
#         observation key ee_pos with shape (516, 3)
#         observation key ee_states with shape (516, 6)
#         observation key eye_in_hand_rgb with shape (516, 128, 128, 3)
#         observation key gripper_states with shape (516, 2)
#         observation key joint_states with shape (516, 7)
#     key: rewards with shape (516,)
#     key: robot_states with shape (516, 9)
#     key: states with shape (516, 47)
# episode demo_35 with 583 transitions
#     key: actions with shape (583, 7)
#     key: dones with shape (583,)
#     key: obs
#         observation key agentview_rgb with shape (583, 128, 128, 3)
#         observation key ee_ori with shape (583, 3)
#         observation key ee_pos with shape (583, 3)
#         observation key ee_states with shape (583, 6)
#         observation key eye_in_hand_rgb with shape (583, 128, 128, 3)
#         observation key gripper_states with shape (583, 2)
#         observation key joint_states with shape (583, 7)
#     key: rewards with shape (583,)
#     key: robot_states with shape (583, 9)
#     key: states with shape (583, 47)
# episode demo_36 with 561 transitions
#     key: actions with shape (561, 7)
#     key: dones with shape (561,)
#     key: obs
#         observation key agentview_rgb with shape (561, 128, 128, 3)
#         observation key ee_ori with shape (561, 3)
#         observation key ee_pos with shape (561, 3)
#         observation key ee_states with shape (561, 6)
#         observation key eye_in_hand_rgb with shape (561, 128, 128, 3)
#         observation key gripper_states with shape (561, 2)
#         observation key joint_states with shape (561, 7)
#     key: rewards with shape (561,)
#     key: robot_states with shape (561, 9)
#     key: states with shape (561, 47)
# episode demo_37 with 521 transitions
#     key: actions with shape (521, 7)
#     key: dones with shape (521,)
#     key: obs
#         observation key agentview_rgb with shape (521, 128, 128, 3)
#         observation key ee_ori with shape (521, 3)
#         observation key ee_pos with shape (521, 3)
#         observation key ee_states with shape (521, 6)
#         observation key eye_in_hand_rgb with shape (521, 128, 128, 3)
#         observation key gripper_states with shape (521, 2)
#         observation key joint_states with shape (521, 7)
#     key: rewards with shape (521,)
#     key: robot_states with shape (521, 9)
#     key: states with shape (521, 47)
# episode demo_38 with 534 transitions
#     key: actions with shape (534, 7)
#     key: dones with shape (534,)
#     key: obs
#         observation key agentview_rgb with shape (534, 128, 128, 3)
#         observation key ee_ori with shape (534, 3)
#         observation key ee_pos with shape (534, 3)
#         observation key ee_states with shape (534, 6)
#         observation key eye_in_hand_rgb with shape (534, 128, 128, 3)
#         observation key gripper_states with shape (534, 2)
#         observation key joint_states with shape (534, 7)
#     key: rewards with shape (534,)
#     key: robot_states with shape (534, 9)
#     key: states with shape (534, 47)
# episode demo_39 with 628 transitions
#     key: actions with shape (628, 7)
#     key: dones with shape (628,)
#     key: obs
#         observation key agentview_rgb with shape (628, 128, 128, 3)
#         observation key ee_ori with shape (628, 3)
#         observation key ee_pos with shape (628, 3)
#         observation key ee_states with shape (628, 6)
#         observation key eye_in_hand_rgb with shape (628, 128, 128, 3)
#         observation key gripper_states with shape (628, 2)
#         observation key joint_states with shape (628, 7)
#     key: rewards with shape (628,)
#     key: robot_states with shape (628, 9)
#     key: states with shape (628, 47)
# episode demo_40 with 618 transitions
#     key: actions with shape (618, 7)
#     key: dones with shape (618,)
#     key: obs
#         observation key agentview_rgb with shape (618, 128, 128, 3)
#         observation key ee_ori with shape (618, 3)
#         observation key ee_pos with shape (618, 3)
#         observation key ee_states with shape (618, 6)
#         observation key eye_in_hand_rgb with shape (618, 128, 128, 3)
#         observation key gripper_states with shape (618, 2)
#         observation key joint_states with shape (618, 7)
#     key: rewards with shape (618,)
#     key: robot_states with shape (618, 9)
#     key: states with shape (618, 47)
# episode demo_41 with 529 transitions
#     key: actions with shape (529, 7)
#     key: dones with shape (529,)
#     key: obs
#         observation key agentview_rgb with shape (529, 128, 128, 3)
#         observation key ee_ori with shape (529, 3)
#         observation key ee_pos with shape (529, 3)
#         observation key ee_states with shape (529, 6)
#         observation key eye_in_hand_rgb with shape (529, 128, 128, 3)
#         observation key gripper_states with shape (529, 2)
#         observation key joint_states with shape (529, 7)
#     key: rewards with shape (529,)
#     key: robot_states with shape (529, 9)
#     key: states with shape (529, 47)
# episode demo_42 with 551 transitions
#     key: actions with shape (551, 7)
#     key: dones with shape (551,)
#     key: obs
#         observation key agentview_rgb with shape (551, 128, 128, 3)
#         observation key ee_ori with shape (551, 3)
#         observation key ee_pos with shape (551, 3)
#         observation key ee_states with shape (551, 6)
#         observation key eye_in_hand_rgb with shape (551, 128, 128, 3)
#         observation key gripper_states with shape (551, 2)
#         observation key joint_states with shape (551, 7)
#     key: rewards with shape (551,)
#     key: robot_states with shape (551, 9)
#     key: states with shape (551, 47)
# episode demo_43 with 572 transitions
#     key: actions with shape (572, 7)
#     key: dones with shape (572,)
#     key: obs
#         observation key agentview_rgb with shape (572, 128, 128, 3)
#         observation key ee_ori with shape (572, 3)
#         observation key ee_pos with shape (572, 3)
#         observation key ee_states with shape (572, 6)
#         observation key eye_in_hand_rgb with shape (572, 128, 128, 3)
#         observation key gripper_states with shape (572, 2)
#         observation key joint_states with shape (572, 7)
#     key: rewards with shape (572,)
#     key: robot_states with shape (572, 9)
#     key: states with shape (572, 47)
# episode demo_44 with 638 transitions
#     key: actions with shape (638, 7)
#     key: dones with shape (638,)
#     key: obs
#         observation key agentview_rgb with shape (638, 128, 128, 3)
#         observation key ee_ori with shape (638, 3)
#         observation key ee_pos with shape (638, 3)
#         observation key ee_states with shape (638, 6)
#         observation key eye_in_hand_rgb with shape (638, 128, 128, 3)
#         observation key gripper_states with shape (638, 2)
#         observation key joint_states with shape (638, 7)
#     key: rewards with shape (638,)
#     key: robot_states with shape (638, 9)
#     key: states with shape (638, 47)
# episode demo_45 with 567 transitions
#     key: actions with shape (567, 7)
#     key: dones with shape (567,)
#     key: obs
#         observation key agentview_rgb with shape (567, 128, 128, 3)
#         observation key ee_ori with shape (567, 3)
#         observation key ee_pos with shape (567, 3)
#         observation key ee_states with shape (567, 6)
#         observation key eye_in_hand_rgb with shape (567, 128, 128, 3)
#         observation key gripper_states with shape (567, 2)
#         observation key joint_states with shape (567, 7)
#     key: rewards with shape (567,)
#     key: robot_states with shape (567, 9)
#     key: states with shape (567, 47)
# episode demo_46 with 536 transitions
#     key: actions with shape (536, 7)
#     key: dones with shape (536,)
#     key: obs
#         observation key agentview_rgb with shape (536, 128, 128, 3)
#         observation key ee_ori with shape (536, 3)
#         observation key ee_pos with shape (536, 3)
#         observation key ee_states with shape (536, 6)
#         observation key eye_in_hand_rgb with shape (536, 128, 128, 3)
#         observation key gripper_states with shape (536, 2)
#         observation key joint_states with shape (536, 7)
#     key: rewards with shape (536,)
#     key: robot_states with shape (536, 9)
#     key: states with shape (536, 47)
# episode demo_47 with 524 transitions
#     key: actions with shape (524, 7)
#     key: dones with shape (524,)
#     key: obs
#         observation key agentview_rgb with shape (524, 128, 128, 3)
#         observation key ee_ori with shape (524, 3)
#         observation key ee_pos with shape (524, 3)
#         observation key ee_states with shape (524, 6)
#         observation key eye_in_hand_rgb with shape (524, 128, 128, 3)
#         observation key gripper_states with shape (524, 2)
#         observation key joint_states with shape (524, 7)
#     key: rewards with shape (524,)
#     key: robot_states with shape (524, 9)
#     key: states with shape (524, 47)
# episode demo_48 with 540 transitions
#     key: actions with shape (540, 7)
#     key: dones with shape (540,)
#     key: obs
#         observation key agentview_rgb with shape (540, 128, 128, 3)
#         observation key ee_ori with shape (540, 3)
#         observation key ee_pos with shape (540, 3)
#         observation key ee_states with shape (540, 6)
#         observation key eye_in_hand_rgb with shape (540, 128, 128, 3)
#         observation key gripper_states with shape (540, 2)
#         observation key joint_states with shape (540, 7)
#     key: rewards with shape (540,)
#     key: robot_states with shape (540, 9)
#     key: states with shape (540, 47)
# episode demo_49 with 662 transitions
#     key: actions with shape (662, 7)
#     key: dones with shape (662,)
#     key: obs
#         observation key agentview_rgb with shape (662, 128, 128, 3)
#         observation key ee_ori with shape (662, 3)
#         observation key ee_pos with shape (662, 3)
#         observation key ee_states with shape (662, 6)
#         observation key eye_in_hand_rgb with shape (662, 128, 128, 3)
#         observation key gripper_states with shape (662, 2)
#         observation key joint_states with shape (662, 7)
#     key: rewards with shape (662,)
#     key: robot_states with shape (662, 9)
#     key: states with shape (662, 47)
#     <video width="640" height="480" controls>
#         <source src="output.mp4" type="video/mp4">
#     </video>
#     <script>
#         var video = document.getElementsByTagName('video')[0];
#         video.playbackRate = 2.0; // Increase the playback speed to 2x
#         </script>

# %% [markdown]
# ### 2.7 Concate multiple datasets for multit-task training

# %%
from torch.utils.data import ConcatDataset, Dataset
from libero.lifelong.datasets import get_dataset, SequenceVLDataset

num_tasks = benchmark_instance.get_num_tasks()
print(f"Number of tasks in the benchmark {benchmark_instance.name}: {num_tasks}")

# manip_datasets = []
# for demo_file in demo_files:
#     task_i_dataset, shape_meta = get_dataset(
#             dataset_path=os.path.join(cfg.folder,
#                                         benchmark.get_task_demonstration(i)),
#             obs_modality=cfg.data.obs.modality,
#             initialize_obs_utils=(i==0),
#             seq_len=cfg.data.seq_len)    
#     manip_datasets.append()

# concat_dataset = ConcatDataset([get_dataset(demo_file) for demo_file in demo_files])
# Out:
# Number of tasks in the benchmark t3: 1

# %% [markdown]
# ### 2.8 Create datasets for Experience Replay algorithm
#
# In the algorithm of ER, we need to sample data from both dataset of the current task and data from previous experiences. To this end, a specific implementation is needed (`TruncatedSequenceDataset`).
